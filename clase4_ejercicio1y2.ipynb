# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import sys
import os
import math

# %% [markdown]
# Clase 4  Ejercicio 1.
# Implementar un programa Python que aplique una transformación  logatitmica a iuna imageen infraexpuesta  de entrada en color con factor de escalado parametrizable

# %%
def log_plot(FactorEscalado):
    x = np.arange(0, 256, 0.01)
    y = FactorEscalado * np.log(1 + x) *10
    plt.plot(x, y, 'r', linewidth=1)
    #plt.rcParams['font.sans-serif']=['SimHei'] 
    plt.title(u'grafica logaritmo')
    plt.xlim(0, 255), plt.ylim(0, 255)
    plt.show()

# %% [markdown]
# > $$
# output = c log[1+e^escalado -1)* r]
# $$
# > $$
# c = MaxR / [log [1+e^sigma - 1) * maxr]
# $$

# %%
def log(FactorEscalado, img):
    # https://stackoverflow.com/questions/21117415/finding-the-value-of-the-min-and-max-pixel
    smallest = img.min(axis=(0, 1))
    largest = img.max(axis=(0, 1))
    
    print(smallest,largest)
    
    maxS = 255
    maxR = largest

    c = maxS/(np.log(1+(math.exp(FactorEscalado)-1)* maxR))

    output  = c * np.log( 1 + ((math.exp(FactorEscalado) - 1) * img))
        
    output = np.uint8(output)
    #log_plot(img, output
    return output

# %%
FactorEscalado = int(input("Introduce factor de escalado: "))
# Out:
# Introduce factor de escalado:  10

# %%
print("El factor de escalado es:", FactorEscalado)
# Out:
# El factor de escalado es: 10

# %%
img = cv2.imread('img/food.jpg')

smallest = img.min(axis=(0, 1))
largest = img.max(axis=(0, 1))
    
print(smallest,largest)
output = log(FactorEscalado, img)
# Out:
# [0 0 0] [205 207 240]
# [0 0 0] [205 207 240]

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
#log_plot(42)

# %%
plt.imshow(output)
plt.imshow(cv2.cvtColor(output, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Clase 4 Ejercicio 2. Implementar un programa Python que aplique una transformación exponencial a una imagen sobrepuesta de entrada en color con factor de escalado parametrizable

# %%
FactorEscalado = int(input("Introduce factor de escalado: "))
# Out:
# Introduce factor de escalado:  5

# %%
print("El factor de escalado es:", FactorEscalado)
FactorEscalado = 100
# Out:
# El factor de escalado es: 5

# %%
def expo(FactorEscalado, img):
    # https://stackoverflow.com/questions/21117415/finding-the-value-of-the-min-and-max-pixel
    smallest = img.min(axis=(0, 1))
    largest = img.max(axis=(0, 1))
    
    print(smallest,largest)
    
    maxS = 255
    maxR = largest

    c = maxS / ((1 + FactorEscalado)^img) - 1

    output  = c * [((1 + FactorEscalado)^maxR)  -1]
        
    output = np.uint8(output)
    #log_plot(img, output
    return output

# %%
img = cv2.imread('img/food.jpg')

smallest = img.min(axis=(0, 1))
largest = img.max(axis=(0, 1))
    
print(smallest,largest)
output = expo(FactorEscalado, img)
# Out:
# [0 0 0] [205 207 240]
# [0 0 0] [205 207 240]
# C:\Users\N63422\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(output, cv2.COLOR_BGR2RGB))
